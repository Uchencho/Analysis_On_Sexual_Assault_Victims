# %% [markdown]
# ## This is my analysis on the Sexual Assault Questionaire Provided

# %%
import numpy as np
import pandas as pd
data = pd.read_excel("Sexual Assault Prevention Questionaire (Responses).xlsx")      #Read in dataset

# %%
data.head()
# Out:
#                 Timestamp What is your current age?  \
# 0 2019-04-17 13:38:40.860                     35-45
# 1 2019-04-17 19:17:05.661                     18-25
# 2 2019-04-17 19:54:41.168                     18-25
# 3 2019-04-17 16:39:57.570                     18-25
# 4 2019-04-17 19:06:38.610                     18-25
#
#   Which of the categories best describe you? How do you identify yourself?  \
# 0                                      White                          Male
# 1                     Asian/Pacific Islander                        Female
# 2                     Asian/Pacific Islander                        Female
# 3                                      Black                        Female
# 4                                      Other                          Male
#
#   Do you own or carry any forms of protection in case of sexual assault, attack, or other potential harm?  \
# 0          No, I do not own any forms of protection.
# 1  No, I do not own or carry any forms of protect...
# 2  No, I do not own or carry any forms of protect...
# 3  No, I do not own or carry any forms of protect...
# 4  No, I do not own or carry any forms of protect...
#
#   Would you buy a product that would help protect you before sexual assault was to occur?  \
# 0  No, I would not buy something to protect me ag...
# 1  Maybe, I would think about buying a product to...
# 2  Maybe, I would think about buying a product to...
# 3  Maybe, I would think about buying a product to...
# 4  No, I would not buy something to protect me ag...
#
#   Have you ever used any commercial DNA testing services (23andMe, Ancestry, etc)?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Have you ever been a victim of sexual assault or rape?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Have you ever witnessed assault or rape?  \
# 0                                      NaN
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   If you answered "Yes" or "Maybe" to "Have you ever been a victim of sexual assault or rape?" or "Have you ever witnessed assault or rape?", did you or the victim file a police report or go to the hospital afterwards?  \
# 0                                                NaN
# 1                                                NaN
# 2  No, I  nor the victim did not go to the hospit...
# 3                                                NaN
# 4  No, I  nor the victim did not go to the hospit...
#
#   If you did not file a police report or go to the hospital, why?  \
# 0                                                 Na
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    How comfortable do you feel going to the authorities (police or hospitals) on a scale of 1 to 10 (where 1 = Very Uncomfortable to 10=Very Comfortable).
# 0                                                NaN
# 1                                                8.0
# 2                                                9.0
# 3                                                9.0
# 4                                                5.0

# %%
#View column names
data.columns
# Out:
# Index(['Timestamp', 'What is your current age?',
#        'Which of the categories best describe you?',
#        'How do you identify yourself?',
#        'Do you own or carry any forms of protection in case of sexual assault, attack, or other potential harm?',
#        'Would you buy a product that would help protect you before sexual assault was to occur?',
#        'Have you ever used any commercial DNA testing services (23andMe, Ancestry, etc)?',
#        'Have you ever been a victim of sexual assault or rape?',
#        'Have you ever witnessed assault or rape?',
#        'If you answered "Yes" or "Maybe" to "Have you ever been a victim of sexual assault or rape?" or "Have you ever witnessed assault or rape?", did you or the victim file a police report or go to the hospital afterwards?',
#        'If you did not file a police report or go to the hospital, why?',
#        'How comfortable do you feel going to the authorities (police or hospitals) on a scale of 1 to 10 (where 1 = Very Uncomfortable to 10=Very Comfortable).'],
#       dtype='object')

# %% [markdown]
# The column names are so long making analysis difficult, i will try to change as many column names as possible.

# %%
data = data.rename(columns= {'Timestamp' : "time",
             'What is your current age?' : 'age',
             'Which of the categories best describe you?' : 'race',
             'How do you identify yourself?' : 'gender',
             'Do you own or carry any forms of protection in case of sexual assault, attack, or other potential harm?' : 'carry_protection',
             'Would you buy a product that would help protect you before sexual assault was to occur?' : 'purchase_sexual_protection',
             'Have you ever used any commercial DNA testing services (23andMe, Ancestry, etc)?' : 'commercial_dna_services',
             'Have you ever been a victim of sexual assault or rape?' : 'assaulted_or_raped',
             'Have you ever witnessed assault or rape?' : 'witness_assault/rape',
             'If you answered "Yes" or "Maybe" to "Have you ever been a victim of sexual assault or rape?" or "Have you ever witnessed assault or rape?", did you or the victim file a police report or go to the hospital afterwards?' : 'police_report/hospital',
             'If you did not file a police report or go to the hospital, why?' : 'why_no_police_report/hospital',
             'How comfortable do you feel going to the authorities (police or hospitals) on a scale of 1 to 10 (where 1 = Very Uncomfortable to 10=Very Comfortable).' : 'report_to_authorities_comfortability'
})
data.columns
# Out:
# Index(['time', 'age', 'race', 'gender', 'carry_protection',
#        'purchase_sexual_protection', 'commercial_dna_services',
#        'assaulted_or_raped', 'witness_assault/rape', 'police_report/hospital',
#        'why_no_police_report/hospital',
#        'report_to_authorities_comfortability'],
#       dtype='object')

# %% [markdown]
# ## This will be used as Reference for the column names in case of confusion
#
# 'What is your current age?' : 'age'
#
# 'Which of the categories best describe you?' : 'race'
#
# 'How do you identify yourself?' : 'gender'
#
# 'Do you own or carry any forms of protection in case of sexual assault, attack, or other potential harm?' : 'carry_protection'
#
# 'Would you buy a product that would help protect you before sexual assault was to occur?' : 'purchase_sexual_protection'
#
# 'Have you ever used any commercial DNA testing services (23andMe, Ancestry, etc)?' : 'commercial_dna_services'
#
# 'Have you ever been a victim of sexual assault or rape?' : 'assaulted_or_raped'
#
# 'Have you ever witnessed assault or rape?' : 'witness_assault/rape'
#
# 'If you answered "Yes" or "Maybe" to "Have you ever been a victim of sexual assault or rape?" or "Have you ever witnessed assault or rape?", did you or the victim file a police report or go to the hospital afterwards?' : 'police_report/hospital'
#
# 'If you did not file a police report or go to the hospital, why?' : 'why_no_police_report/hospital'
#
# 'How comfortable do you feel going to the authorities (police or hospitals) on a scale of 1 to 10 (where 1 = Very Uncomfortable to 10=Very Comfortable).' : 'report_to_authorities_comfortability'

# %%
data.head()
# Out:
#                      time    age                    race  gender  \
# 0 2019-04-17 13:38:40.860  35-45                   White    Male
# 1 2019-04-17 19:17:05.661  18-25  Asian/Pacific Islander  Female
# 2 2019-04-17 19:54:41.168  18-25  Asian/Pacific Islander  Female
# 3 2019-04-17 16:39:57.570  18-25                   Black  Female
# 4 2019-04-17 19:06:38.610  18-25                   Other    Male
#
#                                     carry_protection  \
# 0          No, I do not own any forms of protection.
# 1  No, I do not own or carry any forms of protect...
# 2  No, I do not own or carry any forms of protect...
# 3  No, I do not own or carry any forms of protect...
# 4  No, I do not own or carry any forms of protect...
#
#                           purchase_sexual_protection commercial_dna_services  \
# 0  No, I would not buy something to protect me ag...                      No
# 1  Maybe, I would think about buying a product to...                      No
# 2  Maybe, I would think about buying a product to...                      No
# 3  Maybe, I would think about buying a product to...                      No
# 4  No, I would not buy something to protect me ag...                      No
#
#   assaulted_or_raped witness_assault/rape  \
# 0                 No                  NaN
# 1                 No                   No
# 2                Yes                   No
# 3                 No                   No
# 4                 No                   No
#
#                               police_report/hospital  \
# 0                                                NaN
# 1                                                NaN
# 2  No, I  nor the victim did not go to the hospit...
# 3                                                NaN
# 4  No, I  nor the victim did not go to the hospit...
#
#   why_no_police_report/hospital  report_to_authorities_comfortability
# 0                            Na                                   NaN
# 1                           NaN                                   8.0
# 2                           NaN                                   9.0
# 3                           NaN                                   9.0
# 4                           NaN                                   5.0

# %% [markdown]
# I have cleaned the column names by renaming them to shorter names which i can use to aid my analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 12 columns):
# time                                    1004 non-null datetime64[ns]
# age                                     1004 non-null object
# race                                    1004 non-null object
# gender                                  1004 non-null object
# carry_protection                        1004 non-null object
# purchase_sexual_protection              1004 non-null object
# commercial_dna_services                 1004 non-null object
# assaulted_or_raped                      1004 non-null object
# witness_assault/rape                    1003 non-null object
# police_report/hospital                  444 non-null object
# why_no_police_report/hospital           230 non-null object
# report_to_authorities_comfortability    1003 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 94.2+ KB

# %% [markdown]
# From the result above, we see we have two columns with a lot of nan values, the police_report/hospital and why_no_police_report/hospital columns, i will take a look at the unique values in these columns and decide how to handle them

# %%
data['police_report/hospital'].value_counts(dropna = False)
# Out:
# NaN                                                                                                                 560
# No, I  nor the victim did not go to the hospital or file a police report.                                           264
# Yes, I or the victim went to the police and filled a police report.                                                 104
# Yes, I or the victim went to the hospital and received a sexual assault evidence kit.                                48
# Yes, I or the victim went to the hospital and received a sexual assault evidence kit AND filled a police report.     28
# Name: police_report/hospital, dtype: int64

# %%
data['why_no_police_report/hospital'].value_counts(dropna = False)
# Out:
# NaN                                                                                                                                                                                                                                                                    774
# no                                                                                                                                                                                                                                                                       3
# No                                                                                                                                                                                                                                                                       3
# Scared                                                                                                                                                                                                                                                                   3
# Na                                                                                                                                                                                                                                                                       3
# NO                                                                                                                                                                                                                                                                       3
# yes                                                                                                                                                                                                                                                                      3
# make a complint                                                                                                                                                                                                                                                          3
# make a complaint                                                                                                                                                                                                                                                         2
# NO COMMENTS                                                                                                                                                                                                                                                              2
# fear                                                                                                                                                                                                                                                                     2
# dont know                                                                                                                                                                                                                                                                2
# nothing                                                                                                                                                                                                                                                                  2
# I was 12 and I knew I wouldn't be taken seriously                                                                                                                                                                                                                        1
# I was a kid.                                                                                                                                                                                                                                                             1
# I was young and I was just touched                                                                                                                                                                                                                                       1
# Because it would cost me money and no one would listen anyhow. It would be very humiliating to have to tell people about it.                                                                                                                                             1
# It happened at school and I went to a teacher who said I couldn't prove the other student did anything.                                                                                                                                                                  1
# scared of society                                                                                                                                                                                                                                                        1
# Scared and needed a place for me and my baby to stay at the time and he treaten me.                                                                                                                                                                                      1
# safety and treatment is important.., then report it                                                                                                                                                                                                                      1
# Shame and embarrassment were my reasons                                                                                                                                                                                                                                  1
# Because I was not a victim of sexual assault.                                                                                                                                                                                                                            1
# she is not actually raped, she is harrassed and we helped her                                                                                                                                                                                                            1
# no scared                                                                                                                                                                                                                                                                1
# I was young and thought it was my fault because I was drunk                                                                                                                                                                                                              1
# I never been a victim or never witnessed any.                                                                                                                                                                                                                            1
# \nBecause they raped me when I was a child and I did not know what to do.                                                                                                                                                                                                1
# I didnt think anyone would believe me, i was only assualted and that doesnt really leave any proof like a dna rape kit could be able to find. Its my word against his.                                                                                                   1
# good                                                                                                                                                                                                                                                                     1
#                                                                                                                                                                                                                                                                       ...
# I don't risk my life                                                                                                                                                                                                                                                     1
# Because I felt nobody would believe me                                                                                                                                                                                                                                   1
# Was my husband at the time i did not know you could press charges against a spouse                                                                                                                                                                                       1
# afraid and young                                                                                                                                                                                                                                                         1
# It was an attack by my now ex husband. I was afraid he would kill me if I did.                                                                                                                                                                                           1
# Nothing such happened to me                                                                                                                                                                                                                                              1
# becuase i have never been assaulted or raped or even harrassed                                                                                                                                                                                                           1
# In most cases, you will not need a police report to file a claim with your insurer unless there is extensive damage that you'd like to be compensated for, or something unusual happens                                                                                  1
# no, I avoided it                                                                                                                                                                                                                                                         1
# Fear no one would believe me and I would be blamed                                                                                                                                                                                                                       1
# I did                                                                                                                                                                                                                                                                    1
# I was too scared                                                                                                                                                                                                                                                         1
# Underage when it happened and too afraid to talk. Besides authorities do not believe men can be raped by women                                                                                                                                                           1
# One time I just divorced him, the second time I didn't realize I was being manipulated until many months later                                                                                                                                                           1
# I was molested once by my moms friends' son when I was abround 4 years old while he was babysitting and they decided not to have him around anymore by himself.                                                                                                          1
# I didn't know at that age that it was sexual assault                                                                                                                                                                                                                     1
# I was a child. He was my grandfather. I was punished when I told my parents because when they my siblings they denied it. The abuse went on for several years before they realized I was telling the truth. He also assaulted my younger brother and older sister.       1
# Because by the time I was past denial and opened up to talk about it it was past the time period that any thing could be done legally.                                                                                                                                   1
# I didn't want attention drawn to me.                                                                                                                                                                                                                                     1
# Because it was unnecessary                                                                                                                                                                                                                                               1
# i like this                                                                                                                                                                                                                                                              1
# Lack of moral support from anyone                                                                                                                                                                                                                                        1
# it was an emergency situation for first aid.so i will decide to go hospital                                                                                                                                                                                              1
# I was a child.                                                                                                                                                                                                                                                           1
# Would not have been able to prove it                                                                                                                                                                                                                                     1
# GO TO THE HOSPITAL                                                                                                                                                                                                                                                       1
# I was afraid that the rapist did more to me afterwards                                                                                                                                                                                                                   1
# I was young and stupid, thought it was best not to tell anyone.                                                                                                                                                                                                          1
# because of fear on childhood                                                                                                                                                                                                                                             1
# I was too scared.                                                                                                                                                                                                                                                        1
# Name: why_no_police_report/hospital, Length: 212, dtype: int64

# %% [markdown]
# There is no ideal way to handle both columns especially as the 'why_no_police_report/hospital' column is filled with a lot of unique values. I will look at the time column to see if there is need to split it

# %%
data['time'].value_counts(dropna = False)
# Out:
# 2019-04-20 12:08:42.736    2
# 2019-04-17 20:55:01.549    1
# 2019-04-18 16:53:28.429    1
# 2019-04-18 12:12:22.234    1
# 2019-04-17 18:29:18.518    1
# 2019-04-17 16:05:41.180    1
# 2019-04-20 21:36:50.210    1
# 2019-04-20 20:13:54.909    1
# 2019-04-17 18:00:38.795    1
# 2019-04-17 18:09:33.760    1
# 2019-04-17 21:12:35.668    1
# 2019-04-18 02:45:17.020    1
# 2019-04-17 23:02:19.712    1
# 2019-04-20 16:23:39.004    1
# 2019-04-19 15:33:15.913    1
# 2019-04-20 23:33:30.359    1
# 2019-04-17 16:03:29.702    1
# 2019-04-17 16:45:24.051    1
# 2019-04-17 17:58:36.811    1
# 2019-04-21 21:04:52.792    1
# 2019-04-21 12:57:36.247    1
# 2019-04-19 07:04:30.438    1
# 2019-04-21 16:11:18.456    1
# 2019-04-18 01:37:55.623    1
# 2019-04-17 15:59:20.530    1
# 2019-04-20 13:35:16.158    1
# 2019-04-21 13:36:43.550    1
# 2019-04-17 17:00:57.121    1
# 2019-04-19 10:33:42.550    1
# 2019-04-21 13:51:33.121    1
#                           ..
# 2019-04-17 20:21:51.511    1
# 2019-04-20 03:02:10.842    1
# 2019-04-21 14:36:40.782    1
# 2019-04-20 19:31:20.629    1
# 2019-04-18 10:42:13.337    1
# 2019-04-20 10:58:29.821    1
# 2019-04-21 13:49:57.325    1
# 2019-04-17 18:58:05.334    1
# 2019-04-19 19:31:17.688    1
# 2019-04-20 12:46:16.403    1
# 2019-04-18 10:02:25.703    1
# 2019-04-21 20:40:07.722    1
# 2019-04-20 14:25:00.069    1
# 2019-04-17 17:23:55.920    1
# 2019-04-20 21:54:20.439    1
# 2019-04-21 14:05:10.569    1
# 2019-04-17 20:44:48.798    1
# 2019-04-18 11:42:28.808    1
# 2019-04-17 16:00:16.033    1
# 2019-04-17 16:27:23.450    1
# 2019-04-17 23:00:43.463    1
# 2019-04-21 00:18:30.791    1
# 2019-04-19 11:48:01.950    1
# 2019-04-20 11:55:37.388    1
# 2019-04-21 00:54:05.283    1
# 2019-04-21 10:40:00.323    1
# 2019-04-21 09:17:13.872    1
# 2019-04-17 20:50:02.593    1
# 2019-04-17 21:17:08.826    1
# 2019-04-20 17:41:01.031    1
# Name: time, Length: 1003, dtype: int64

# %% [markdown]
# From the result above, looks like the data was collated in April 2019, I will create a day and time column to see if there is any interesting pattern there.

# %%
import datetime as dt

data['day'] = data['time'].dt.day                                #extracted the day
data["hour"] = data["time"].dt.hour                              #extracted the hour

data.head()
# Out:
#                      time    age                    race  gender  \
# 0 2019-04-17 13:38:40.860  35-45                   White    Male
# 1 2019-04-17 19:17:05.661  18-25  Asian/Pacific Islander  Female
# 2 2019-04-17 19:54:41.168  18-25  Asian/Pacific Islander  Female
# 3 2019-04-17 16:39:57.570  18-25                   Black  Female
# 4 2019-04-17 19:06:38.610  18-25                   Other    Male
#
#                                     carry_protection  \
# 0          No, I do not own any forms of protection.
# 1  No, I do not own or carry any forms of protect...
# 2  No, I do not own or carry any forms of protect...
# 3  No, I do not own or carry any forms of protect...
# 4  No, I do not own or carry any forms of protect...
#
#                           purchase_sexual_protection commercial_dna_services  \
# 0  No, I would not buy something to protect me ag...                      No
# 1  Maybe, I would think about buying a product to...                      No
# 2  Maybe, I would think about buying a product to...                      No
# 3  Maybe, I would think about buying a product to...                      No
# 4  No, I would not buy something to protect me ag...                      No
#
#   assaulted_or_raped witness_assault/rape  \
# 0                 No                  NaN
# 1                 No                   No
# 2                Yes                   No
# 3                 No                   No
# 4                 No                   No
#
#                               police_report/hospital  \
# 0                                                NaN
# 1                                                NaN
# 2  No, I  nor the victim did not go to the hospit...
# 3                                                NaN
# 4  No, I  nor the victim did not go to the hospit...
#
#   why_no_police_report/hospital  report_to_authorities_comfortability  day  \
# 0                            Na                                   NaN   17
# 1                           NaN                                   8.0   17
# 2                           NaN                                   9.0   17
# 3                           NaN                                   9.0   17
# 4                           NaN                                   5.0   17
#
#    hour
# 0    13
# 1    19
# 2    19
# 3    16
# 4    19

# %% [markdown]
# I have created two new columns, the day and hour coulmn which was extracted from the time column

# %%
data['hour'].value_counts(dropna = False)
# Out:
# 16    121
# 21     63
# 19     62
# 20     59
# 18     47
# 0      46
# 17     46
# 11     45
# 22     44
# 13     43
# 12     43
# 10     43
# 14     40
# 15     37
# 2      35
# 23     35
# 9      28
# 1      28
# 8      27
# 6      25
# 7      23
# 4      22
# 3      22
# 5      20
# Name: hour, dtype: int64

# %% [markdown]
# From the hour column, I will create a new column that allows us to see easily if the data was collated in the early hours of the day, morning, afternoon, evening or night

# %%
def hour_segment(x):
    if 0 <= x < 6:
        return "early_morning"
    elif 6 <= x < 12:
        return "morning"
    elif 12 <= x < 16:
        return "afternoon"
    elif 16 <= x < 19:
        return "evening"
    elif 19 <= x < 24:
        return "night"

data['period_of_day'] = data['hour'].apply(hour_segment)
data['period_of_day'].value_counts(dropna = False)
# Out:
# night            263
# evening          214
# morning          191
# early_morning    173
# afternoon        163
# Name: period_of_day, dtype: int64

# %% [markdown]
# We have created extra columns highlighting the day of April 2019, hour(24-hr format) and period of the day that the data was collated. The minute and second was not extracted because it was not deemed necessary. We will continue cleaning the data by looking at more columns, next is the age column.

# %%
data['gender'].value_counts(dropna = False)
# Out:
# Female               537
# Male                 461
# Prefer not to say      3
# Nonbinary              1
# agender                1
# Genderqueer            1
# Name: gender, dtype: int64

# %% [markdown]
# The gender column would have been cleaned but because the frequency of male and female far outweigh the others, I will leave it as it is.

# %%
data['assaulted_or_raped'].value_counts(dropna = False)
# Out:
# No       677
# Yes      259
# Maybe     68
# Name: assaulted_or_raped, dtype: int64

# %% [markdown]
# I would like to segment the data based on those who responded maybe, to assaulted or raped to see their gender, age and time they responded, maybe a pattern can be drawn
#
# This is done so because, the question is such that the response should be binary

# %%
maybe = data[data['assaulted_or_raped'] == 'Maybe']
maybe.head()
# Out:
#                       time    age                    race  gender  \
# 16 2019-04-17 17:59:03.041  18-25                   White    Male
# 24 2019-04-17 21:41:14.194  18-25                Hispanic  Female
# 41 2019-04-18 09:40:22.738  18-25                   Black  Female
# 46 2019-04-18 15:42:11.425  18-25                   White  Female
# 54 2019-04-19 11:41:39.310  18-25  Asian/Pacific Islander  Female
#
#                                      carry_protection  \
# 16  No, I do not own or carry any forms of protect...
# 24  No, I do not own or carry any forms of protect...
# 41  No, I do not own or carry any forms of protect...
# 46  No, I do not own or carry any forms of protect...
# 54  No, I do not own or carry any forms of protect...
#
#                            purchase_sexual_protection commercial_dna_services  \
# 16  Yes, I would buy a product that would help pro...                     Yes
# 24  Maybe, I would think about buying a product to...                      No
# 41  Yes, I would buy a product that would help pro...                      No
# 46  Maybe, I would think about buying a product to...                     Yes
# 54  Yes, I would buy a product that would help pro...                      No
#
#    assaulted_or_raped witness_assault/rape  \
# 16              Maybe                   No
# 24              Maybe                  Yes
# 41              Maybe                   No
# 46              Maybe                   No
# 54              Maybe                   No
#
#                                police_report/hospital  \
# 16  No, I  nor the victim did not go to the hospit...
# 24                                                NaN
# 41  No, I  nor the victim did not go to the hospit...
# 46  No, I  nor the victim did not go to the hospit...
# 54  No, I  nor the victim did not go to the hospit...
#
#                         why_no_police_report/hospital  \
# 16  Was not sure of the detail I would need to go ...
# 24  I did not know at the time what was considered...
# 41                                                NaN
# 46                                                NaN
# 54          i was a child and did not know any better
#
#     report_to_authorities_comfortability  day  hour period_of_day
# 16                                   8.0   17    17       evening
# 24                                   8.0   17    21         night
# 41                                   4.0   18     9       morning
# 46                                  10.0   18    15     afternoon
# 54                                   5.0   19    11       morning

# %%
maybe['gender'].value_counts(dropna = False)
# Out:
# Female    46
# Male      22
# Name: gender, dtype: int64

# %% [markdown]
# This looks like more men responded to Maybe because the general dataset had a ratio of about 1:1.1, while the maybe dataset has a ratio of 2:1. This could be because men are ashamed to admit they were raped.
#
# We will return to the general dataset as we might have seen the underlying reason for the Maybe response.

# %%
data['purchase_sexual_protection'].value_counts(dropna = False)
# Out:
# Yes, I would buy a product that would help protect me against sexual assault.                                     465
# Maybe, I would think about buying a product to help protect me against sexual assault.                            320
# No, I would not buy something to protect me against sexual assault or rape, but would buy it for someone else.    141
# No, I would not buy a product that would help protect me against sexual assault.                                   78
# Name: purchase_sexual_protection, dtype: int64

# %% [markdown]
# Although tempted to convert this into a binary response, the third response with 141 occurrences in an interesting data that should not be lost

# %%
data['commercial_dna_services'].value_counts(dropna = False)
# Out:
# No     779
# Yes    225
# Name: commercial_dna_services, dtype: int64

# %% [markdown]
# This is great, i will convert this column into Boolean expression

# %%
yes_no = {'Yes' : True, 'No' : False}
data['commercial_dna_services'] = data['commercial_dna_services'].map(yes_no)
data['commercial_dna_services'].value_counts(dropna = False)
# Out:
# False    779
# True     225
# Name: commercial_dna_services, dtype: int64

# %%
data['witness_assault/rape'].value_counts(dropna = False)
# Out:
# No     830
# Yes    173
# NaN      1
# Name: witness_assault/rape, dtype: int64

# %% [markdown]
# Same thing, i will convert this too boolean too and set the NaN value to false

# %%
import numpy as np
yes_no_NaN = {'Yes' : True, 'No' : False, np.NaN: False}
data['witness_assault/rape'] = data['witness_assault/rape'].map(yes_no_NaN)
data['witness_assault/rape'].value_counts(dropna = False)
# Out:
# False    831
# True     173
# Name: witness_assault/rape, dtype: int64

# %%
data.head()
# Out:
#                      time    age                    race  gender  \
# 0 2019-04-17 13:38:40.860  35-45                   White    Male
# 1 2019-04-17 19:17:05.661  18-25  Asian/Pacific Islander  Female
# 2 2019-04-17 19:54:41.168  18-25  Asian/Pacific Islander  Female
# 3 2019-04-17 16:39:57.570  18-25                   Black  Female
# 4 2019-04-17 19:06:38.610  18-25                   Other    Male
#
#                                     carry_protection  \
# 0          No, I do not own any forms of protection.
# 1  No, I do not own or carry any forms of protect...
# 2  No, I do not own or carry any forms of protect...
# 3  No, I do not own or carry any forms of protect...
# 4  No, I do not own or carry any forms of protect...
#
#                           purchase_sexual_protection  commercial_dna_services  \
# 0  No, I would not buy something to protect me ag...                    False
# 1  Maybe, I would think about buying a product to...                    False
# 2  Maybe, I would think about buying a product to...                    False
# 3  Maybe, I would think about buying a product to...                    False
# 4  No, I would not buy something to protect me ag...                    False
#
#   assaulted_or_raped  witness_assault/rape  \
# 0                 No                 False
# 1                 No                 False
# 2                Yes                 False
# 3                 No                 False
# 4                 No                 False
#
#                               police_report/hospital  \
# 0                                                NaN
# 1                                                NaN
# 2  No, I  nor the victim did not go to the hospit...
# 3                                                NaN
# 4  No, I  nor the victim did not go to the hospit...
#
#   why_no_police_report/hospital  report_to_authorities_comfortability  day  \
# 0                            Na                                   NaN   17
# 1                           NaN                                   8.0   17
# 2                           NaN                                   9.0   17
# 3                           NaN                                   9.0   17
# 4                           NaN                                   5.0   17
#
#    hour period_of_day
# 0    13     afternoon
# 1    19         night
# 2    19         night
# 3    16       evening
# 4    19         night

# %% [markdown]
# ## I have succeeded in cleaning the data by renaming columns for easy analysis, creating new columns to analyse and convert some columns to boolean values.
#
# ## We will now start the analysis.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['assaulted_or_raped'].value_counts().plot(kind = 'bar', 
                                               title = "Assaulted or Raped Distribution",
                                              figsize = (9,5),
                                               rot = 45)
plt.show()

# %%
data['age'].value_counts().plot(kind = 'bar', 
                                title = "Age Distribution",
                                figsize = (9,5),
                                rot = 45)
plt.show()

# %% [markdown]
# This shows that majority of those who took the survey are Youths and Adults Under 35.

# %%
data['report_to_authorities_comfortability'].value_counts().iloc[[5,9,7,8,6,3,2,1,4,0]].plot(kind = 'bar', 
                                                                                             title = 'Ratings Distribution Showing How Comfortable People are Reporting to the Authorities',
                                                                                             figsize = (10,5),
                                                                                             rot = 45)
plt.xlabel('Individual Ratings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This plot tell us that a large number of people are comfortable reporting to the Authorities in case of a rape case.

# %%
data['commercial_dna_services'].value_counts().plot(kind = 'pie', 
                                                    title = 'Pie Chart showing the Use of Commercial DNA Services',
                                                   figsize = (8,8),
                                                    autopct = '%.2f%%',
                                                   colormap = plt.cm.BuGn_r)
plt.ylabel('')
plt.show()

# %% [markdown]
# This shows that a lot of people are not willing to use commercial dna services

# %%
data['report_to_authorities_comfortability'].value_counts().iloc[[5,9,7,8,6,3,2,1,4,0]].plot(kind = 'bar', 
                                                                                             title = 'Ratings Distribution Showing How Comfortable People are Reporting to the Authorities',
                                                                                             figsize = (10,5),
                                                                                             rot = 45)
plt.xlabel('Individual Ratings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This shows that a lot of people are not willing to use commercial dna services

# %%
data['purchase_sexual_protection'].value_counts().plot(kind = 'barh', 
                                                       title = 'General Distribution of prople willing to Purchase Sexual Protection tools')
plt.show()

# %%
data['carry_protection'].value_counts().plot(kind = 'barh', title = 'Distribution of People that carry protection')
plt.show()

# %% [markdown]
# This plot shows a lot of people do not ownn or carry any form of protection

# %%
data['gender'].value_counts().plot(kind = 'bar',
                                  figsize = (10,5),
                                  rot = 45,
                                  title = 'Frequency Distribution of the Genders who took the Survey')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This shows that more females took the survey

# %%
data['assaulted_or_raped'].value_counts().plot(kind = 'bar',
                                              title = 'Frequency Distribution of Rape/Assaulted Victims',
                                              figsize = (9,5),
                                              colormap = plt.cm.Accent)
plt.show()

# %% [markdown]
# For those who say they were raped, i would expect a structured response to some questions like if they will carry protection and use dna servise. I will take a look.

# %%
rape_victims = data[data['assaulted_or_raped'] == "Yes"]
rape_victims['carry_protection'].value_counts().plot(kind = 'barh', 
                                                     title = "Distribution of Rape Victims that Carry protection")
plt.show()

# %% [markdown]
# Yes there is a difference, rate drop from 5:1 to 2:1 (roughly) although the difference is not as significant as i expected.

# %%
rape_victims['purchase_sexual_protection'].value_counts().plot(kind = 'barh', 
                                                               title = 'Distribution of Rape Victims that will Purchase Sexual Protection')
plt.show()

# %%
data['report_to_authorities_comfortability'].value_counts().iloc[[5,9,7,8,6,3,2,1,4,0]].plot(kind = 'bar', 
                                                                                             title = 'Ratings Distribution Showing How Comfortable People are Reporting to the Authorities',
                                                                                             figsize = (6,2),
                                                                                             rot = 45)
plt.xlabel('Individual Ratings')
plt.ylabel('Frequency')
plt.show()

# %%
rape_victims['report_to_authorities_comfortability'].value_counts().iloc[[0,3,4,9,8,7,2,5,6]].plot(kind = 'bar', 
                                    title = 'Ratings Distribution of the comfortability of reporting cases by Rape Victims',
                                    figsize = (8,3),
                                    rot = 45,                                                                 
                                                                                                    )
plt.ylabel('Frequency')
plt.xlabel('Ratings')
plt.show()

# %% [markdown]
# We repeated the plot so that we can compare quite easily the difference between both plots
#
# We can see a different scenario when we look at the response of rape victims, Most of them are not comfortable reporting to the authorities.

# %%
rape_victims['gender'].value_counts().plot(kind = 'pie',
                                           figsize = (8,8),
                                           autopct = '%.2f%%',
                                           title = "Pie chart of Rape Victims")
plt.ylabel('')
plt.show()

# %% [markdown]
# Narrowing down into Gender distribution of rape victims, we see the women, as expected, have a significant higher count

# %%
rape_victims[rape_victims['gender'] == "Female"]['carry_protection'].value_counts().plot(kind = 'barh', 
                                                                                         title = "Women who will Carry Protection")
plt.show()

# %% [markdown]
# Since we know that it is majorly females who are rape victims, we checked to see if they will be willing to carry protection as seen above.

# %%
data['purchase_sexual_protection'].value_counts().plot(kind = 'pie',
                                                       figsize= (9,9),
                                                       autopct = '%.2f%%',
                                                       title = 'Pie chart showing If people will Purchase Sexual Protection Tools')
plt.ylabel('')
plt.show()

# %%
rape_victims['purchase_sexual_protection'].value_counts().plot(kind = 'pie',
                                                               figsize = (9,9),
                                                               autopct = '%.2f%%',
                                                               title = 'Pie chart showing If Rape Victims will Purchase Sexual Protection Tools')
plt.ylabel('')
plt.show()

# %%
rape_victims[rape_victims['gender'] == "Female"]['purchase_sexual_protection'].value_counts().plot(kind = 'pie',
                                                                                                   figsize= (8,8),
                                                                                                   autopct = '%.2f%%',
                                                                                                   title =  'Pie chart showing If Female Rape Victims will Purchase Sexual Protection Tools')
plt.ylabel('')
plt.show()

# %% [markdown]
# To fully illustrate the difference in opinion between rape victims and the general public, on if they are willing to puchase protection incase of Rape, we use pie chart to compare as seen above. Focusing on the red colored area, we can see that it is smaller for rape victims, meaning more people are willing to buy.
#
# Also, we notice, the female gender who are higher recipients of rape and assault are even more willing to purchase these tools.

# %%
data['period_of_day'].value_counts().sort_values().plot(kind = 'barh', 
                                                        title = 'Time Period The General Public took the Survey',
                                                       figsize = (9,5),
                                                       colormap =plt.cm.Accent_r)
plt.xlabel('Frequency')
plt.show()

# %%
rape_victims['period_of_day'].value_counts().sort_values().plot(kind = 'barh', 
                                                                title = 'Time Period Rape Victims took the Survey',
                                                               figsize = (9,5),
                                                               colormap = plt.cm.BuGn_r)
plt.xlabel('Frequency')
plt.show()

# %% [markdown]
# Both the general dataset and the segmented data were filled in the late hours of the day, this is not surprising when we remember the majority of those who took the survey are between 25-35, the working class age, so it is expected they will have the time to fill it at the end of the day when they are less busy.
